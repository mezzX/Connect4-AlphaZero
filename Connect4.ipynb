# %% [markdown]
# **Import Your Agent**
#
# Import your agent here to have it play the game

# %%
import connect4
from play import Play
from test_agent import MinimaxPlayerTest
from agents import MinimaxPlayer
from agent_zero import Connect4Zero

# %% [markdown]
# **Set Players**
#
# Assign your agent to either p1 or p2 to have it take that player slot
#
# Use None to have that player be human controlled.
#
# Use MinimaxPlayer() to have that player be the test agent

# %%
p1 = Connect4Zero()
p2 = MinimaxPlayerTest()
game = connect4.Connect4()

# %% [markdown]
# Run the cell below to start the game.
#
# In a game with at least 1 human player, click a column to drop a piece into that column

# %%
# %matplotlib notebook
Play(game, p2, p1)
# Out:
# <img src="data:image/png;base64,..." width="333">
